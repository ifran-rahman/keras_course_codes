# %% [markdown]
# # Details
# This a sample project of mine to refresh related concepts.
# Say in your a university, generally people who's average CGPA is more than or equal 3.7 tend to get A in Neural Network course, likewise who's CGPA is >= 3.3 gets A - and who's CGPA is >= 3 tend to get B+ maximum time.
# We'll first build a sample dataset and then make a deeplearning model, which will predict someone's grade in Neural Network course based on his average CGPA.
#
# We'll consider A as 0, A- as 1, B+ as 2

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy

# %% [markdown]
# **Sample Dataset Building**
# Here we are making a sample dataset. <br>
# Where for 90% of the students, <br>
# CGPA>=3.7 A ~ 0 <br>
# CGPA>=3.3 A- ~ 1 <br>
# CGPA>=3.0 B+ ~ 2 <br>
#
# Where for 3% of the students,<br>
# CGPA>=3.3 A- ~ 1 <br>
# CGPA>=3.7 A ~ 0 <br>
# CGPA>=3.0 B+ ~ 2 <br>
#
# Where for 3% of the students,<br>
# CGPA>=3.3 A- ~ 1 <br>
# CGPA>=3.0 B+ ~ 2 <br>
# CGPA>=3.7 A ~ 0 <br>
#
# Where for 3% of the students,<br>
# CGPA>=3.7 A ~ 0 <br>
# CGPA>=3.0 B+ ~ 2 <br>
# CGPA>=3.3 A- ~ 1 <br>

# %%
import numpy as np
import sklearn
from random import randint
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
import random
train_labels=[]
train_samples = []

for i in range(910):
    # The ~90% of students who's average CGPA is greater than or equal 3.7
    random_student_A = random.uniform(3.7,4)
    train_samples.append(random_student_A)
    train_labels.append(0)

    # The ~90% of students who's average CGPA is greater than or equal 3.3
    random_student_A_minus = random.uniform(3.3,3.69)
    train_samples.append(random_student_A_minus)
    train_labels.append(1)
    
    # The ~90% of students who's average CGPA is greater than or equal 3.3
    random_student_B_plus= random.uniform(3.00,3.29)
    train_samples.append(random_student_B_plus)
    train_labels.append(2)
    

for i in range(30):
     # The ~3% of students who's average CGPA is greater than or equal 3.7
    random_student_A = random.uniform(3.7,4)
    train_samples.append(random_student_A)
    train_labels.append(1)

    # The ~3% of students who's average CGPA is greater than or equal 3.3
    random_student_A_minus = random.uniform(3.3,3.69)
    train_samples.append(random_student_A_minus)
    train_labels.append(0)
    
    # The ~3% of students who's average CGPA is greater than or equal 3.3
    random_student_B_plus= random.uniform(3.00,3.29)
    train_samples.append(random_student_B_plus)
    train_labels.append(2)
    
for i in range(30):
       # The ~3% of students who's average CGPA is greater than or equal 3.7
    random_student_A = random.uniform(3.7,4)
    train_samples.append(random_student_A)
    train_labels.append(1)

    # The ~3% of students who's average CGPA is greater than or equal 3.3
    random_student_A_minus = random.uniform(3.3,3.69)
    train_samples.append(random_student_A_minus)
    train_labels.append(2)
    
    # The ~3% of students who's average CGPA is greater than or equal 3.3
    random_student_B_plus= random.uniform(3.00,3.29)
    train_samples.append(random_student_B_plus)
    train_labels.append(0)
    
for i in range(30):
      # The ~3% of students who's average CGPA is greater than or equal 3.7
    random_student_A = random.uniform(3.7,4)
    train_samples.append(random_student_A)
    train_labels.append(0)

    # The ~3% of students who's average CGPA is greater than or equal 3.3
    random_student_A_minus = random.uniform(3.3,3.69)
    train_samples.append(random_student_A_minus)
    train_labels.append(2)
    
    # The ~3% of students who's average CGPA is greater than or equal 3.3
    random_student_B_plus= random.uniform(3.00,3.29)
    train_samples.append(random_student_B_plus)
    train_labels.append(1)


train_labels = np.array(train_labels)
train_samples = np.array(train_samples)
train_labels, train_samples = shuffle(train_labels, train_samples)

# for i,j in zip(train_samples,train_labels):
#     print(str(i) + "," + str(j))


scaler = MinMaxScaler(feature_range=(0,1))
scaled_train_samples = scaler.fit_transform(train_samples.reshape(-1,1))

for i in scaled_train_samples:
   print(i)
# Out:
# [0.66723149]
# [0.01599654]
# [0.64469557]
# [0.22562873]
# [0.72587083]
# [0.91087308]
# [0.45135988]
# [0.18331073]
# [0.41169931]
# [0.963379]
# [0.03133344]
# [0.57264673]
# [0.47287373]
# [0.74191919]
# [0.13732337]
# [0.21579676]
# [0.35656992]
# [0.39251688]
# [0.02503206]
# [0.82193369]
# [0.47594052]
# [0.09486319]
# [0.15888847]
# [0.4461222]
# [0.74315803]
# [0.6329053]
# [0.01411701]
# [0.79697061]
# [0.59215242]
# [0.78295892]
# [0.40559518]
# [0.78746031]
# [0.03851339]
# [0.79770139]
# [0.80241622]
# [0.9734416]
# [0.8732004]
# [0.48718568]
# [0.53035721]
# [0.0749232]
# [0.99793564]
# [0.4192876]
# [0.89643031]
# [0.16932353]
# [0.84082778]
# [0.97576903]
# [0.37611753]
# [0.86101663]
# [0.46354247]
# [0.7863132]
# [0.00718484]
# [0.84620154]
# [0.31203405]
# [0.90417887]
# [0.04646539]
# [0.1607698]
# [0.89645601]
# [0.45398558]
# [0.16118884]
# [0.78794478]
# [0.3925377]
# [0.68888572]
# [0.74644011]
# [0.80081384]
# [0.70438637]
# [0.7845304]
# [0.21098123]
# ...

# %%
model = model.fit(x=scaled_train_samples, y=train_labels, batch_size=10, epochs=30, validation_split = 0.1,verbose=2)([
    Dense(units = 16, input_shape=(1,), activation = 'relu'),
    Dense(units = 32, activation = 'relu'),
    Dense(units = 64, activation = 'relu'),
    Dense(units = 128, activation = 'relu'),
    Dense(units = 3, activation = 'softmax'),
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 16)                32
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 387
# ...
# Total params: 11,395
# Trainable params: 11,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=scaled_train_samples, y=train_labels, batch_size=10, epochs=30, validation_split = 0.1,verbose=2)
# Out:
# Epoch 1/30
# 270/270 - 1s - loss: 1.0375 - accuracy: 0.5359 - val_loss: 0.9380 - val_accuracy: 0.6733
# Epoch 2/30
# 270/270 - 0s - loss: 0.7762 - accuracy: 0.6996 - val_loss: 0.6412 - val_accuracy: 0.7533
# Epoch 3/30
# 270/270 - 0s - loss: 0.5488 - accuracy: 0.8189 - val_loss: 0.5199 - val_accuracy: 0.8400
# Epoch 4/30
# 270/270 - 0s - loss: 0.4558 - accuracy: 0.8730 - val_loss: 0.4762 - val_accuracy: 0.8900
# Epoch 5/30
# 270/270 - 0s - loss: 0.4195 - accuracy: 0.8989 - val_loss: 0.4650 - val_accuracy: 0.9100
# Epoch 6/30
# 270/270 - 0s - loss: 0.4041 - accuracy: 0.9093 - val_loss: 0.4527 - val_accuracy: 0.9000
# Epoch 7/30
# 270/270 - 0s - loss: 0.3947 - accuracy: 0.9141 - val_loss: 0.4485 - val_accuracy: 0.9000
# Epoch 8/30
# 270/270 - 0s - loss: 0.3883 - accuracy: 0.9144 - val_loss: 0.4460 - val_accuracy: 0.9000
# Epoch 9/30
# 270/270 - 0s - loss: 0.3834 - accuracy: 0.9159 - val_loss: 0.4384 - val_accuracy: 0.9133
# Epoch 10/30
# ...

# %% [markdown]
# # Testing
# Normally we build a test set and test with that. However I'll test with only one or two datas. Say a student has average CGPA of 3.78 and another has 3.32 last one has 3.02.

# %%
test_samples = np.array([3.78, 3.32, 3.02])
scaled_test_samples = scaler.fit_transform(test_samples.reshape(-1,1))
predictions = model.predict(x=scaled_test_samples,batch_size=10,verbose=0)
for i in predictions:
    print(i)
# Out:
# [9.7014856e-01 2.9198235e-02 6.5318274e-04]
# [0.01937801 0.90151966 0.07910229]
# [0.0198927  0.01769791 0.96240944]

# %%
rounded_predictions = np.argmax(predictions, axis=-1)

for i in rounded_predictions:
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# So, we can see the result is as expected. If one has average cgpa of 3.87 he would get A, 3.32 would <br>
# get A- and 3.02 would get B+. Which is exactly what should happen for the most part.
